# %% [markdown]
# <a href="https://colab.research.google.com/github/Mithunmahendran/Mithunmahendran/blob/main/pandas_notes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
a=np.linspace(1,100,10)

# %%
a={"a":0,"b":1,"c":2}

# %%
a
# Out:
# {'a': 0, 'b': 1, 'c': 2}

# %% [markdown]
# #**Pandas**

# %%
e=pd.Series(a)

# %%
e
# Out:
# a    0
# b    1
# c    2
# dtype: int64

# %%
data = {"a": [1,2,3],
        "b": [4,5,6],
        "c": [7,8,9]}

# %%
df9=pd.DataFrame(data)

# %%
df9
# Out:
#    a  b  c
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9

# %%
datas = {"A": [6],
        "B": [8]}

# %%
dfq=pd.DataFrame(datas)

# %%
dfq
# Out:
#    A  B
# 0  6  8

# %%
arr=np.random.randint(0,200,(5,4))

# %%
arr
# Out:
# array([[ 84,  58, 162,  53],
#        [107,  18, 117,  85],
#        [ 28, 153,   6, 138],
#        [164, 126,  13, 100],
#        [170, 183, 152, 175]])

# %%
arr1=np.random.randint(0,1000,(5,5))

# %%
arr1
# Out:
# array([[441, 294, 354, 500, 853],
#        [210, 312, 916, 552, 360],
#        [229, 494, 808, 456, 762],
#        [106, 537, 102, 269, 257],
#        [203, 768, 493, 172, 279]])

# %%
rows=['mon','tues','wed','thurs','fri']
columns=['Jan','Feb','Marc','Apr','May']

# %%
dft=pd.DataFrame(arr1,index=rows,columns=columns)

# %%
dft
# Out:
#        Jan  Feb  Marc  Apr  May
# mon    441  294   354  500  853
# tues   210  312   916  552  360
# wed    229  494   808  456  762
# thurs  106  537   102  269  257
# fri    203  768   493  172  279

# %%
rownames=['Mon','Tue','Wed','Thur','Fri']
Columnnames=['Jan','Feb','Marc','Apr']

# %%
df8=pd.DataFrame(arr,index=rownames,columns=Columnnames)

# %%
df8
# Out:
#       Jan  Feb  Marc  Apr
# Mon    84   58   162   53
# Tue   107   18   117   85
# Wed    28  153     6  138
# Thur  164  126    13  100
# Fri   170  183   152  175

# %%
path="/content/weather_data.csv"

# %%
dfw=pd.read_csv(path)

# %%
dfw
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
dfw.head(3)
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow

# %%
dfw.tail(2)
# Out:
#         day  temperature  windspeed  event
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
dfw.shape
# Out:
# (6, 4)

# %%
dfw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          6 non-null      object
#  1   temperature  6 non-null      int64
#  2   windspeed    6 non-null      int64
#  3   event        6 non-null      object
# dtypes: int64(2), object(2)
# memory usage: 320.0+ bytes

# %%
dfw.columns
# Out:
# Index(['day', 'temperature', 'windspeed', 'event'], dtype='object')

# %%
dfw.rename(columns={"windspeed":"wind-speed"},inplace=True)

# %%
dfw
# Out:
#         day  temperature  wind-speed  event
# 0  1/1/2017           32           6   Rain
# 1  1/2/2017           35           7  Sunny
# 2  1/3/2017           28           2   Snow
# 3  1/4/2017           24           7   Snow
# 4  1/5/2017           32           4   Rain
# 5  1/6/2017           31           2  Sunny

# %%
dfw.rename(columns={"temperature":"Choodu"},inplace=True)

# %%
dfw
# Out:
#         day  Choodu  wind-speed  event
# 0  1/1/2017      32           6   Rain
# 1  1/2/2017      35           7  Sunny
# 2  1/3/2017      28           2   Snow
# 3  1/4/2017      24           7   Snow
# 4  1/5/2017      32           4   Rain
# 5  1/6/2017      31           2  Sunny

# %%
dfw.rename(str.upper,axis='columns')
# Out:
#         DAY  CHOODU  WIND-SPEED  EVENT
# 0  1/1/2017      32           6   Rain
# 1  1/2/2017      35           7  Sunny
# 2  1/3/2017      28           2   Snow
# 3  1/4/2017      24           7   Snow
# 4  1/5/2017      32           4   Rain
# 5  1/6/2017      31           2  Sunny

# %%
dfw.rename(lambda x:x.replace("-","_"),axis='columns',inplace=True)

# %%
dfw['day']
# Out:
# 0    1/1/2017
# 1    1/2/2017
# 2    1/3/2017
# 3    1/4/2017
# 4    1/5/2017
# 5    1/6/2017
# Name: day, dtype: object

# %%
dfw['event']
# Out:
# 0     Rain
# 1    Sunny
# 2     Snow
# 3     Snow
# 4     Rain
# 5    Sunny
# Name: event, dtype: object

# %%
dfw['event'].value_counts()
# Out:
# event
# Rain     2
# Sunny    2
# Snow     2
# Name: count, dtype: int64

# %%
dfw['event'].unique()
# Out:
# array(['Rain', 'Sunny', 'Snow'], dtype=object)

# %%
dfw['day'][dfw['Choodu']==dfw.Choodu.max()]
# Out:
# 1    1/2/2017
# Name: day, dtype: object

# %%
dfw['day'][dfw["Choodu"]>dfw.Choodu.mean()]
# Out:
# 0    1/1/2017
# 1    1/2/2017
# 4    1/5/2017
# 5    1/6/2017
# Name: day, dtype: object

# %%
dfw.rename(columns={'Choodu':'temperature'},inplace=True)

# %%
dfw
# Out:
#         day  temperature  wind_speed  event
# 0  1/1/2017           32           6   Rain
# 1  1/2/2017           35           7  Sunny
# 2  1/3/2017           28           2   Snow
# 3  1/4/2017           24           7   Snow
# 4  1/5/2017           32           4   Rain
# 5  1/6/2017           31           2  Sunny

# %%
dfw['temperature']
# Out:
# 0    32
# 1    35
# 2    28
# 3    24
# 4    32
# 5    31
# Name: temperature, dtype: int64

# %%
dfw[['day','temperature','event']][dfw['temperature']>dfw.temperature.mean()]
# Out:
#         day  temperature  event
# 0  1/1/2017           32   Rain
# 1  1/2/2017           35  Sunny
# 4  1/5/2017           32   Rain
# 5  1/6/2017           31  Sunny

# %%
dfw['day'][dfw['temperature']==dfw.temperature.max()]
# Out:
# 1    1/2/2017
# Name: day, dtype: object

# %%
dfw[dfw['temperature']>30]
# Out:
#         day  temperature  wind_speed  event
# 0  1/1/2017           32           6   Rain
# 1  1/2/2017           35           7  Sunny
# 4  1/5/2017           32           4   Rain
# 5  1/6/2017           31           2  Sunny

# %%
dfw
# Out:
#         day  temperature  wind_speed  event
# 0  1/1/2017           32           6   Rain
# 1  1/2/2017           35           7  Sunny
# 2  1/3/2017           28           2   Snow
# 3  1/4/2017           24           7   Snow
# 4  1/5/2017           32           4   Rain
# 5  1/6/2017           31           2  Sunny

# %%
dfw[(dfw['temperature']<30) | (dfw['wind_speed']>5)]
# Out:
#         day  temperature  wind_speed  event
# 0  1/1/2017           32           6   Rain
# 1  1/2/2017           35           7  Sunny
# 2  1/3/2017           28           2   Snow
# 3  1/4/2017           24           7   Snow

# %%
dfw[(dfw['temperature']>30) & (dfw['wind_speed']<5) | (dfw['temperature']<30) & (dfw['wind_speed']>5)]
# Out:
#         day  temperature  wind_speed  event
# 3  1/4/2017           24           7   Snow
# 4  1/5/2017           32           4   Rain
# 5  1/6/2017           31           2  Sunny

# %%
dfw['temperature'][(dfw['temperature']>30) & (dfw['wind_speed']<5) | (dfw['temperature']<30) & (dfw['wind_speed']>5)]
# Out:
# 3    24
# 4    32
# 5    31
# Name: temperature, dtype: int64

# %%
dfw[['temperature','wind_speed']][(dfw['temperature']>30) & (dfw['wind_speed']<5) | (dfw['temperature']<30) & (dfw['wind_speed']>5)]
# Out:
#    temperature  wind_speed
# 3           24           7
# 4           32           4
# 5           31           2

# %%
path="/content/Titanic-Dataset.csv"

# %%
df=pd.read_csv(path)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
passengers_survived=df[df['Survived']==1]

# %%
passengers_survived
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# 875                   Najib, Miss. Adele Kiamie "Jane"  female  15.0      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 8        2            347742  11.1333   NaN        S
# 9        0            237736  30.0708   NaN        C
# ..     ...               ...      ...   ...      ...
# 875      0              2667   7.2250   NaN        C
# 879      1             11767  83.1583   C50        C
# 880      1            230433  26.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 889      0            111369  30.0000  C148        C
#
# [342 rows x 12 columns]

# %%
First_class= df[df['Pclass']==1]

# %%
First_class
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 11            12         1       1
# 23            24         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# ..                                                 ...     ...   ...    ...
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 872                           Carlsson, Mr. Frans Olof    male  33.0      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
#
#      Parch    Ticket     Fare        Cabin Embarked
# 1        0  PC 17599  71.2833          C85        C
# 3        0    113803  53.1000         C123        S
# 6        0     17463  51.8625          E46        S
# 11       0    113783  26.5500         C103        S
# 23       0    113788  35.5000           A6        S
# ..     ...       ...      ...          ...      ...
# 871      1     11751  52.5542          D35        S
# 872      0       695   5.0000  B51 B53 B55        S
# 879      1     11767  83.1583          C50        C
# 887      0    112053  30.0000          B42        S
# 889      0    111369  30.0000         C148        C
#
# [216 rows x 12 columns]

# %%
Fare_greater_first= df[(df['Fare']>50) & (df['Pclass']==1)]

# %%
Fare_greater_first
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 27            28         0       1
# 31            32         1       1
# ..           ...       ...     ...
# 849          850         1       1
# 856          857         1       1
# 867          868         0       1
# 871          872         1       1
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 27                      Fortune, Mr. Charles Alexander    male  19.0      3
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# ..                                                 ...     ...   ...    ...
# 849       Goldenberg, Mrs. Samuel L (Edwiga Grabowska)  female   NaN      1
# 856         Wick, Mrs. George Dennick (Mary Hitchcock)  female  45.0      1
# 867               Roebling, Mr. Washington Augustus II    male  31.0      0
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
#
#      Parch    Ticket      Fare        Cabin Embarked
# 1        0  PC 17599   71.2833          C85        C
# 3        0    113803   53.1000         C123        S
# 6        0     17463   51.8625          E46        S
# 27       2     19950  263.0000  C23 C25 C27        S
# 31       0  PC 17569  146.5208          B78        C
# ..     ...       ...       ...          ...      ...
# 849      0     17453   89.1042          C92        C
# 856      1     36928  164.8667          NaN        S
# 867      0  PC 17590   50.4958          A24        S
# 871      1     11751   52.5542          D35        S
# 879      1     11767   83.1583          C50        C
#
# [139 rows x 12 columns]

# %%
Female_Younger= df[(df['Sex']=='female') & (df['Age']<30)]

# %%
Female_Younger
# Out:
#      PassengerId  Survived  Pclass  \
# 2              3         1       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 14            15         0       3
# ..           ...       ...     ...
# 874          875         1       2
# 875          876         1       3
# 880          881         1       2
# 882          883         0       3
# 887          888         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 14                Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# ..                                                 ...     ...   ...    ...
# 874              Abelson, Mrs. Samuel (Hannah Wizosky)  female  28.0      1
# 875                   Najib, Miss. Adele Kiamie "Jane"  female  15.0      0
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0      0
# 882                       Dahlberg, Miss. Gerda Ulrika  female  22.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 8        2            347742  11.1333   NaN        S
# 9        0            237736  30.0708   NaN        C
# 10       1           PP 9549  16.7000    G6        S
# 14       0            350406   7.8542   NaN        S
# ..     ...               ...      ...   ...      ...
# 874      0         P/PP 3381  24.0000   NaN        C
# 875      0              2667   7.2250   NaN        C
# 880      1            230433  26.0000   NaN        S
# 882      0              7552  10.5167   NaN        S
# 887      0            112053  30.0000   B42        S
#
# [147 rows x 12 columns]

# %%
Second_class_Sib= df[(df['Pclass']==2) | (df['SibSp']>0)]

# %%
Second_class_Sib
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 3              4         1       1
# 7              8         0       3
# 9             10         1       2
# ..           ...       ...     ...
# 874          875         1       2
# 880          881         1       2
# 883          884         0       2
# 886          887         0       2
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 7                       Palsson, Master. Gosta Leonard    male   2.0      3
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# 874              Abelson, Mrs. Samuel (Hannah Wizosky)  female  28.0      1
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0      0
# 883                      Banfield, Mr. Frederick James    male  28.0      0
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 3        0            113803  53.1000  C123        S
# 7        1            349909  21.0750   NaN        S
# 9        0            237736  30.0708   NaN        C
# ..     ...               ...      ...   ...      ...
# 874      0         P/PP 3381  24.0000   NaN        C
# 880      1            230433  26.0000   NaN        S
# 883      0  C.A./SOTON 34068  10.5000   NaN        S
# 886      0            211536  13.0000   NaN        S
# 888      2        W./C. 6607  23.4500   NaN        S
#
# [403 rows x 12 columns]

# %%
Female_Twenty = df[(df['Sex']=='female') & (df['Fare']<20)]

# %%
Female_Twenty
# Out:
#      PassengerId  Survived  Pclass  \
# 2              3         1       3
# 8              9         1       3
# 10            11         1       3
# 14            15         0       3
# 15            16         1       2
# ..           ...       ...     ...
# 858          859         1       3
# 865          866         1       2
# 866          867         1       2
# 875          876         1       3
# 882          883         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 14                Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# ..                                                 ...     ...   ...    ...
# 858              Baclini, Mrs. Solomon (Latifa Qurban)  female  24.0      0
# 865                           Bystrom, Mrs. (Karolina)  female  42.0      0
# 866                       Duran y More, Miss. Asuncion  female  27.0      1
# 875                   Najib, Miss. Adele Kiamie "Jane"  female  15.0      0
# 882                       Dahlberg, Miss. Gerda Ulrika  female  22.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 8        2            347742  11.1333   NaN        S
# 10       1           PP 9549  16.7000    G6        S
# 14       0            350406   7.8542   NaN        S
# 15       0            248706  16.0000   NaN        S
# ..     ...               ...      ...   ...      ...
# 858      3              2666  19.2583   NaN        C
# 865      0            236852  13.0000   NaN        S
# 866      0     SC/PARIS 2149  13.8583   NaN        C
# 875      0              2667   7.2250   NaN        C
# 882      0              7552  10.5167   NaN        S
#
# [142 rows x 12 columns]

# %%
Dead_ones_third = df[(df['Survived']==0) & (df['Pclass']==3)]

# %%
Dead_ones_third
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# 12            13         0       3            Saundercock, Mr. William Henry
# ..           ...       ...     ...                                       ...
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch           Ticket     Fare Cabin Embarked
# 0      male  22.0      1      0        A/5 21171   7.2500   NaN        S
# 4      male  35.0      0      0           373450   8.0500   NaN        S
# 5      male   NaN      0      0           330877   8.4583   NaN        Q
# 7      male   2.0      3      1           349909  21.0750   NaN        S
# 12     male  20.0      0      0        A/5. 2151   8.0500   NaN        S
# ..      ...   ...    ...    ...              ...      ...   ...      ...
# 882  female  22.0      0      0             7552  10.5167   NaN        S
# 884    male  25.0      0      0  SOTON/OQ 392076   7.0500   NaN        S
# 885  female  39.0      0      5           382652  29.1250   NaN        Q
# 888  female   NaN      1      2       W./C. 6607  23.4500   NaN        S
# 890    male  32.0      0      0           370376   7.7500   NaN        Q
#
# [372 rows x 12 columns]

# %%
Alive_Second= df[(df['Pclass']==2) | (df['Fare']>30) & (df['Survived']==1)]

# %%
Alive_Second
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 9             10         1       2
# 15            16         1       2
# 17            18         1       2
# ..           ...       ...     ...
# 874          875         1       2
# 879          880         1       1
# 880          881         1       2
# 883          884         0       2
# 886          887         0       2
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 17                        Williams, Mr. Charles Eugene    male   NaN      0
# ..                                                 ...     ...   ...    ...
# 874              Abelson, Mrs. Samuel (Hannah Wizosky)  female  28.0      1
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0      0
# 883                      Banfield, Mr. Frederick James    male  28.0      0
# 886                              Montvila, Rev. Juozas    male  27.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 1        0          PC 17599  71.2833   C85        C
# 3        0            113803  53.1000  C123        S
# 9        0            237736  30.0708   NaN        C
# 15       0            248706  16.0000   NaN        S
# 17       0            244373  13.0000   NaN        S
# ..     ...               ...      ...   ...      ...
# 874      0         P/PP 3381  24.0000   NaN        C
# 879      1             11767  83.1583   C50        C
# 880      1            230433  26.0000   NaN        S
# 883      0  C.A./SOTON 34068  10.5000   NaN        S
# 886      0            211536  13.0000   NaN        S
#
# [307 rows x 12 columns]

# %%
Female_old_Survived= df[(df['Sex']=='female') & (df['Age']>40) & (df['Fare']>50) & (df['Survived']==1)]

# %%
Female_old_Survived
# Out:
#      PassengerId  Survived  Pclass  \
# 52            53         1       1
# 195          196         1       1
# 268          269         1       1
# 275          276         1       1
# 299          300         1       1
# 337          338         1       1
# 366          367         1       1
# 380          381         1       1
# 496          497         1       1
# 513          514         1       1
# 523          524         1       1
# 571          572         1       1
# 591          592         1       1
# 754          755         1       2
# 765          766         1       1
# 779          780         1       1
# 820          821         1       1
# 829          830         1       1
# 856          857         1       1
# 871          872         1       1
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# 195                               Lurette, Miss. Elise  female  58.0      0
# 268      Graham, Mrs. William Thompson (Edith Junkins)  female  58.0      0
# 275                  Andrews, Miss. Kornelia Theodosia  female  63.0      1
# 299    Baxter, Mrs. James (Helene DeLaudeniere Chaput)  female  50.0      0
# 337                    Burns, Miss. Elizabeth Margaret  female  41.0      0
# 366   Warren, Mrs. Frank Manley (Anna Sophia Atkinson)  female  60.0      1
# 380                              Bidois, Miss. Rosalie  female  42.0      0
# 496                     Eustis, Miss. Elizabeth Mussey  female  54.0      1
# 513     Rothschild, Mrs. Martin (Elizabeth L. Barrett)  female  54.0      1
# 523    Hippach, Mrs. Louis Albert (Ida Sophia Fischer)  female  44.0      0
# 571      Appleton, Mrs. Edward Dale (Charlotte Lamson)  female  53.0      2
# 591    Stephenson, Mrs. Walter Bertram (Martha Eustis)  female  52.0      1
# 754                   Herman, Mrs. Samuel (Jane Laver)  female  48.0      1
# 765               Hogeboom, Mrs. John C (Anna Andrews)  female  51.0      1
# 779  Robert, Mrs. Edward Scott (Elisabeth Walton Mc...  female  43.0      0
# 820  Hays, Mrs. Charles Melville (Clara Jennings Gr...  female  52.0      1
# 829          Stone, Mrs. George Nelson (Martha Evelyn)  female  62.0      0
# 856         Wick, Mrs. George Dennick (Mary Hitchcock)  female  45.0      1
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
#
#      Parch    Ticket      Fare    Cabin Embarked
# 52       0  PC 17572   76.7292      D33        C
# 195      0  PC 17569  146.5208      B80        C
# 268      1  PC 17582  153.4625     C125        S
# 275      0     13502   77.9583       D7        S
# 299      1  PC 17558  247.5208  B58 B60        C
# 337      0     16966  134.5000      E40        C
# 366      0    110813   75.2500      D37        C
# 380      0  PC 17757  227.5250      NaN        C
# 496      0     36947   78.2667      D20        C
# 513      0  PC 17603   59.4000      NaN        C
# 523      1    111361   57.9792      B18        C
# 571      0     11769   51.4792     C101        S
# 591      0     36947   78.2667      D20        C
# 754      2    220845   65.0000      NaN        S
# 765      0     13502   77.9583      D11        S
# 779      1     24160  211.3375       B3        S
# 820      1     12749   93.5000      B69        S
# 829      0    113572   80.0000      B28      NaN
# 856      1     36928  164.8667      NaN        S
# 871      1     11751   52.5542      D35        S
# 879      1     11767   83.1583      C50        C

# %%
path="/content/weather_data.csv"

# %%
dfw=pd.read_csv(path)

# %%
dfw
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
dfw.loc[0,'event']
# Out:
# 'Rain'

# %%
dfw.loc[0:3,['event','temperature']]
# Out:
#    event  temperature
# 0   Rain           32
# 1  Sunny           35
# 2   Snow           28
# 3   Snow           24

# %%
dfw.loc[[1,3,4],['event','temperature','windspeed']]
# Out:
#    event  temperature  windspeed
# 1  Sunny           35          7
# 3   Snow           24          7
# 4   Rain           32          4

# %%
dfw.set_index('day',inplace=True)

# %%
dfw
# Out:
#           temperature  windspeed  event
# day
# 1/1/2017           32          6   Rain
# 1/2/2017           35          7  Sunny
# 1/3/2017           28          2   Snow
# 1/4/2017           24          7   Snow
# 1/5/2017           32          4   Rain
# 1/6/2017           31          2  Sunny

# %%
dfw.loc['1/1/2017':'1/6/2017',['event','temperature','windspeed']]
# Out:
#           event  temperature  windspeed
# day
# 1/1/2017   Rain           32          6
# 1/2/2017  Sunny           35          7
# 1/3/2017   Snow           28          2
# 1/4/2017   Snow           24          7
# 1/5/2017   Rain           32          4
# 1/6/2017  Sunny           31          2

# %%
data = pd.DataFrame({'Brand': ['Maruti', 'Hyundai', 'Tata',
                               'Mahindra', 'Maruti', 'Hyundai',
                               'Renault', 'Tata', 'Maruti'],
                     'Year': [2012, 2014, 2011, 2015, 2012,
                              2016, 2014, 2018, 2019],
                     'Kms Driven': [50000, 30000, 60000,
                                    25000, 10000, 46000,
                                    31000, 15000, 12000],
                     'City': ['Gurgaon', 'Delhi', 'Mumbai',
                              'Delhi', 'Mumbai', 'Delhi',
                              'Mumbai', 'Chennai',  'Ghaziabad'],
                     'Mileage':  [28, 27, 25, 26, 28,
                                  29, 24, 21, 24]})

# %%
data
# Out:
#       Brand  Year  Kms Driven       City  Mileage
# 0    Maruti  2012       50000    Gurgaon       28
# 1   Hyundai  2014       30000      Delhi       27
# 2      Tata  2011       60000     Mumbai       25
# 3  Mahindra  2015       25000      Delhi       26
# 4    Maruti  2012       10000     Mumbai       28
# 5   Hyundai  2016       46000      Delhi       29
# 6   Renault  2014       31000     Mumbai       24
# 7      Tata  2018       15000    Chennai       21
# 8    Maruti  2019       12000  Ghaziabad       24

# %%
data.loc[(data['Brand']=='Maruti')&(data['Mileage']>25)]
# Out:
#     Brand  Year  Kms Driven     City  Mileage
# 0  Maruti  2012       50000  Gurgaon       28
# 4  Maruti  2012       10000   Mumbai       28

# %%
data.loc[(data['Brand']=='Maruti')&(data['Mileage']>25),['City','Year']]
# Out:
#       City  Year
# 0  Gurgaon  2012
# 4   Mumbai  2012

# %%
data
# Out:
#       Brand  Year  Kms Driven       City  Mileage
# 0    Maruti  2012       50000    Gurgaon       28
# 1   Hyundai  2014       30000      Delhi       27
# 2      Tata  2011       60000     Mumbai       25
# 3  Mahindra  2015       25000      Delhi       26
# 4    Maruti  2012       10000     Mumbai       28
# 5   Hyundai  2016       46000      Delhi       29
# 6   Renault  2014       31000     Mumbai       24
# 7      Tata  2018       15000    Chennai       21
# 8    Maruti  2019       12000  Ghaziabad       24

# %%
data.iloc[0:3,:]
# Out:
#      Brand  Year  Kms Driven     City  Mileage
# 0   Maruti  2012       50000  Gurgaon       28
# 1  Hyundai  2014       30000    Delhi       27
# 2     Tata  2011       60000   Mumbai       25

# %%
data.iloc[[0,1,2],[2,3]]
# Out:
#    Kms Driven     City
# 0       50000  Gurgaon
# 1       30000    Delhi
# 2       60000   Mumbai

# %%
path="/content/Titanic-Dataset.csv"

# %%
df=pd.read_csv(path)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df.loc[(df['Survived']==1) & (df['Age']>18)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 874          875         1       2
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# 874              Abelson, Mrs. Samuel (Hannah Wizosky)  female  28.0      1
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 8        2            347742  11.1333   NaN        S
# 11       0            113783  26.5500  C103        S
# ..     ...               ...      ...   ...      ...
# 874      0         P/PP 3381  24.0000   NaN        C
# 879      1             11767  83.1583   C50        C
# 880      1            230433  26.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 889      0            111369  30.0000  C148        C
#
# [220 rows x 12 columns]

# %%
df.loc[(df['Survived']==1) & (df['Age']>18),['Name','Pclass']]
# Out:
#                                                   Name  Pclass
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...       1
# 2                               Heikkinen, Miss. Laina       3
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)       3
# 11                            Bonnell, Miss. Elizabeth       1
# ..                                                 ...     ...
# 874              Abelson, Mrs. Samuel (Hannah Wizosky)       2
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)       1
# 880       Shelley, Mrs. William (Imanita Parrish Hall)       2
# 887                       Graham, Miss. Margaret Edith       1
# 889                              Behr, Mr. Karl Howell       1
#
# [220 rows x 2 columns]

# %%
df.loc[ (df['Sex']=='male') & (df['Age']>40)]
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 33            34         0       2           Wheadon, Mr. Edward H  male
# 35            36         0       1  Holverson, Mr. Alexander Oskar  male
# 54            55         0       1  Ostby, Mr. Engelhart Cornelius  male
# 62            63         0       1     Harris, Mr. Henry Birkhardt  male
# ..           ...       ...     ...                             ...   ...
# 845          846         0       3             Abbing, Mr. Anthony  male
# 851          852         0       3             Svensson, Mr. Johan  male
# 857          858         1       1          Daly, Mr. Peter Denis   male
# 860          861         0       3         Hansen, Mr. Claus Peter  male
# 873          874         0       3     Vander Cruyssen, Mr. Victor  male
#
#       Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 6    54.0      0      0       17463  51.8625   E46        S
# 33   66.0      0      0  C.A. 24579  10.5000   NaN        S
# 35   42.0      1      0      113789  52.0000   NaN        S
# 54   65.0      0      1      113509  61.9792   B30        C
# 62   45.0      1      0       36973  83.4750   C83        S
# ..    ...    ...    ...         ...      ...   ...      ...
# 845  42.0      0      0   C.A. 5547   7.5500   NaN        S
# 851  74.0      0      0      347060   7.7750   NaN        S
# 857  51.0      0      0      113055  26.5500   E17        S
# 860  41.0      2      0      350026  14.1083   NaN        S
# 873  47.0      0      0      345765   9.0000   NaN        S
#
# [102 rows x 12 columns]

# %%
df.loc[(df['Sex']=='male') & (df["Age"]>40),['Name','Pclass']]
# Out:
#                                Name  Pclass
# 6           McCarthy, Mr. Timothy J       1
# 33            Wheadon, Mr. Edward H       2
# 35   Holverson, Mr. Alexander Oskar       1
# 54   Ostby, Mr. Engelhart Cornelius       1
# 62      Harris, Mr. Henry Birkhardt       1
# ..                              ...     ...
# 845             Abbing, Mr. Anthony       3
# 851             Svensson, Mr. Johan       3
# 857          Daly, Mr. Peter Denis        1
# 860         Hansen, Mr. Claus Peter       3
# 873     Vander Cruyssen, Mr. Victor       3
#
# [102 rows x 2 columns]

# %%
df.loc[(df['Pclass']==3) & (df['Age']<20) & (df['SibSp']>0), ['Name','Pclass','Fare']]
# Out:
#                                                 Name  Pclass     Fare
# 7                     Palsson, Master. Gosta Leonard       3  21.0750
# 10                   Sandstrom, Miss. Marguerite Rut       3  16.7000
# 16                              Rice, Master. Eugene       3  29.1250
# 24                     Palsson, Miss. Torborg Danira       3  21.0750
# 38                Vander Planke, Miss. Augusta Maria       3  18.0000
# 39                       Nicola-Yarred, Miss. Jamila       3  11.2417
# 49     Arnold-Franchi, Mrs. Josef (Josefine Franchi)       3  17.8000
# 50                        Panula, Master. Juha Niilo       3  39.6875
# 59                Goodwin, Master. William Frederick       3  46.9000
# 63                             Skoog, Master. Harald       3  27.9000
# 68                   Andersson, Miss. Erna Alexandra       3   7.9250
# 71                        Goodwin, Miss. Lillian Amy       3  46.9000
# 86                            Ford, Mr. William Neal       3  34.3750
# 111                             Zabour, Miss. Hileni       3  14.4542
# 119                Andersson, Miss. Ellis Anna Maria       3  31.2750
# 125                     Nicola-Yarred, Master. Elias       3  11.2417
# 147                 Ford, Miss. Robina Maggie "Ruby"       3  34.3750
# 164                     Panula, Master. Eino Viljami       3  39.6875
# 171                             Rice, Master. Arthur       3  29.1250
# 172                     Johnson, Miss. Eleanor Ileen       3  11.1333
# 175                           Klasen, Mr. Klas Albin       3   7.8542
# 182            Asplund, Master. Clarence Gustaf Hugo       3  31.3875
# 192  Andersen-Jensen, Miss. Carla Christine Nielsine       3   7.8542
# 233                   Asplund, Miss. Lillian Gertrud       3  31.3875
# 261                Asplund, Master. Edvin Rojj Felix       3  31.3875
# 266                        Panula, Mr. Ernesti Arvid       3  39.6875
# 278                               Rice, Master. Eric       3  29.1250
# 333                  Vander Planke, Mr. Leo Edmondus       3  18.0000
# 348           Coutts, Master. William Loch "William"       3  15.9000
# 352                               Elias, Mr. Tannous       3   7.2292
# 371                        Wiklund, Mr. Jakob Alfred       3   6.4958
# 374                       Palsson, Miss. Stina Viola       3  21.0750
# 386                  Goodwin, Master. Sidney Leonard       3  46.9000
# 424                      Rosblom, Mr. Viktor Richard       3  20.2125
# 448                   Baclini, Miss. Marie Catherine       3  19.2583
# 469                    Baclini, Miss. Helene Barbara       3  19.2583
# 480                   Goodwin, Master. Harold Victor       3  46.9000
# 489            Coutts, Master. Eden Leslie "Neville"       3  15.9000
# 532                             Elias, Mr. Joseph Jr       3   7.2292
# 541             Andersson, Miss. Ingeborg Constanzia       3  31.2750
# 542                Andersson, Miss. Sigrid Elisabeth       3  31.2750
# 634                               Skoog, Miss. Mabel       3  27.9000
# 642                    Skoog, Miss. Margit Elizabeth       3  27.9000
# 644                           Baclini, Miss. Eugenie       3  19.2583
# 683                      Goodwin, Mr. Charles Edward       3  46.9000
# 686                         Panula, Mr. Jaako Arnold       3  39.6875
# 721                        Jensen, Mr. Svend Lauritz       3   7.0542
# 746                      Abbott, Mr. Rossmore Edward       3  20.2500
# 787                        Rice, Master. George Hugh       3  29.1250
# 788                       Dean, Master. Bertram Vere       3  20.5750
# 813               Andersson, Miss. Ebba Iris Alfrida       3  31.2750
# 819                     Skoog, Master. Karl Thorsten       3  27.9000
# 824                     Panula, Master. Urho Abraham       3  39.6875
# 830          Yasbeck, Mrs. Antoni (Selini Alexander)       3  14.4542
# 850          Andersson, Master. Sigvard Harald Elias       3  31.2750
# 852                          Boulos, Miss. Nourelain       3  15.2458
# 869                  Johnson, Master. Harold Theodor       3  11.1333

# %%
df.loc[(df['Age']<10) | (df['Age']>60) & (df['Survived']==1)]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 7              8         0       3             Palsson, Master. Gosta Leonard
# 10            11         1       3            Sandstrom, Miss. Marguerite Rut
# 16            17         0       3                       Rice, Master. Eugene
# 24            25         0       3              Palsson, Miss. Torborg Danira
# 43            44         1       2   Laroche, Miss. Simonne Marie Anne Andree
# ..           ...       ...     ...                                        ...
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
# 831          832         1       2            Richards, Master. George Sibley
# 850          851         0       3    Andersson, Master. Sigvard Harald Elias
# 852          853         0       3                    Boulos, Miss. Nourelain
# 869          870         1       3            Johnson, Master. Harold Theodor
#
#         Sex    Age  SibSp  Parch         Ticket     Fare Cabin Embarked
# 7      male   2.00      3      1         349909  21.0750   NaN        S
# 10   female   4.00      1      1        PP 9549  16.7000    G6        S
# 16     male   2.00      4      1         382652  29.1250   NaN        Q
# 24   female   8.00      3      1         349909  21.0750   NaN        S
# 43   female   3.00      1      2  SC/Paris 2123  41.5792   NaN        C
# ..      ...    ...    ...    ...            ...      ...   ...      ...
# 829  female  62.00      0      0         113572  80.0000   B28      NaN
# 831    male   0.83      1      1          29106  18.7500   NaN        S
# 850    male   4.00      4      2         347082  31.2750   NaN        S
# 852  female   9.00      1      1           2678  15.2458   NaN        C
# 869    male   4.00      1      1         347742  11.1333   NaN        S
#
# [67 rows x 12 columns]

# %%
df.loc[(df['Age']<10) | (df['Age']>60) & (df['Survived']==1),['Name','Pclass']]
# Out:
#                                           Name  Pclass
# 7               Palsson, Master. Gosta Leonard       3
# 10             Sandstrom, Miss. Marguerite Rut       3
# 16                        Rice, Master. Eugene       3
# 24               Palsson, Miss. Torborg Danira       3
# 43    Laroche, Miss. Simonne Marie Anne Andree       2
# ..                                         ...     ...
# 829  Stone, Mrs. George Nelson (Martha Evelyn)       1
# 831            Richards, Master. George Sibley       2
# 850    Andersson, Master. Sigvard Harald Elias       3
# 852                    Boulos, Miss. Nourelain       3
# 869            Johnson, Master. Harold Theodor       3
#
# [67 rows x 2 columns]

# %%
df.loc[0:3,['Name','Age']]
# Out:
#                                                 Name   Age
# 0                            Braund, Mr. Owen Harris  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                             Heikkinen, Miss. Laina  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0

# %%
df.loc[[0,1,2,3],['Name','Age','Pclass']]
# Out:
#                                                 Name   Age  Pclass
# 0                            Braund, Mr. Owen Harris  22.0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0       1
# 2                             Heikkinen, Miss. Laina  26.0       3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0       1

# %%
df.set_index('Name',inplace=True)

# %%
df
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
# ...                                                         ...       ...
# Montvila, Rev. Juozas                                       887         0
# Graham, Miss. Margaret Edith                                888         1
# Johnston, Miss. Catherine Helen "Carrie"                    889         0
# Behr, Mr. Karl Howell                                       890         1
# Dooley, Mr. Patrick                                         891         0
#
#                                                     Pclass     Sex   Age  \
# Name
# Braund, Mr. Owen Harris                                  3    male  22.0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
# Allen, Mr. William Henry                                 3    male  35.0
# ...                                                    ...     ...   ...
# Montvila, Rev. Juozas                                    2    male  27.0
# Graham, Miss. Margaret Edith                             1  female  19.0
# Johnston, Miss. Catherine Helen "Carrie"                 3  female   NaN
# Behr, Mr. Karl Howell                                    1    male  26.0
# Dooley, Mr. Patrick                                      3    male  32.0
#
#                                                     SibSp  Parch  \
# Name
# Braund, Mr. Owen Harris                                 1      0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...      1      0
# Heikkinen, Miss. Laina                                  0      0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)            1      0
# Allen, Mr. William Henry                                0      0
# ...                                                   ...    ...
# Montvila, Rev. Juozas                                   0      0
# Graham, Miss. Margaret Edith                            0      0
# Johnston, Miss. Catherine Helen "Carrie"                1      2
# Behr, Mr. Karl Howell                                   0      0
# Dooley, Mr. Patrick                                     0      0
#
#                                                               Ticket     Fare  \
# Name
# Braund, Mr. Owen Harris                                    A/5 21171   7.2500
# Cumings, Mrs. John Bradley (Florence Briggs Tha...          PC 17599  71.2833
# Heikkinen, Miss. Laina                              STON/O2. 3101282   7.9250
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  113803  53.1000
# Allen, Mr. William Henry                                      373450   8.0500
# ...                                                              ...      ...
# Montvila, Rev. Juozas                                         211536  13.0000
# Graham, Miss. Margaret Edith                                  112053  30.0000
# Johnston, Miss. Catherine Helen "Carrie"                  W./C. 6607  23.4500
# Behr, Mr. Karl Howell                                         111369  30.0000
# Dooley, Mr. Patrick                                           370376   7.7500
#
#                                                    Cabin Embarked
# Name
# Braund, Mr. Owen Harris                              NaN        S
# Cumings, Mrs. John Bradley (Florence Briggs Tha...   C85        C
# Heikkinen, Miss. Laina                               NaN        S
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        C123        S
# Allen, Mr. William Henry                             NaN        S
# ...                                                  ...      ...
# Montvila, Rev. Juozas                                NaN        S
# Graham, Miss. Margaret Edith                         B42        S
# Johnston, Miss. Catherine Helen "Carrie"             NaN        S
# Behr, Mr. Karl Howell                               C148        C
# Dooley, Mr. Patrick                                  NaN        Q
#
# [891 rows x 11 columns]

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#                                                   Name  PassengerId  Survived  \
# 0                              Braund, Mr. Owen Harris            1         0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...            2         1
# 2                               Heikkinen, Miss. Laina            3         1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)            4         1
# 4                             Allen, Mr. William Henry            5         0
# ..                                                 ...          ...       ...
# 886                              Montvila, Rev. Juozas          887         0
# 887                       Graham, Miss. Margaret Edith          888         1
# 888           Johnston, Miss. Catherine Helen "Carrie"          889         0
# 889                              Behr, Mr. Karl Howell          890         1
# 890                                Dooley, Mr. Patrick          891         0
#
#      Pclass     Sex   Age  SibSp  Parch            Ticket     Fare Cabin  \
# 0         3    male  22.0      1      0         A/5 21171   7.2500   NaN
# 1         1  female  38.0      1      0          PC 17599  71.2833   C85
# 2         3  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN
# 3         1  female  35.0      1      0            113803  53.1000  C123
# 4         3    male  35.0      0      0            373450   8.0500   NaN
# ..      ...     ...   ...    ...    ...               ...      ...   ...
# 886       2    male  27.0      0      0            211536  13.0000   NaN
# 887       1  female  19.0      0      0            112053  30.0000   B42
# 888       3  female   NaN      1      2        W./C. 6607  23.4500   NaN
# 889       1    male  26.0      0      0            111369  30.0000  C148
# 890       3    male  32.0      0      0            370376   7.7500   NaN
#
#     Embarked
# 0          S
# 1          C
# 2          S
# 3          S
# 4          S
# ..       ...
# 886        S
# 887        S
# 888        S
# 889        C
# 890        Q
#
# [891 rows x 12 columns]

# %%
df.loc[0:4,['Name','Pclass','Age']]
# Out:
#                                                 Name  Pclass   Age
# 0                            Braund, Mr. Owen Harris       3  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...       1  38.0
# 2                             Heikkinen, Miss. Laina       3  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1  35.0
# 4                           Allen, Mr. William Henry       3  35.0

# %%
df.iloc[0:3,:]
# Out:
#                                                 Name  PassengerId  Survived  \
# 0                            Braund, Mr. Owen Harris            1         0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...            2         1
# 2                             Heikkinen, Miss. Laina            3         1
#
#    Pclass     Sex   Age  SibSp  Parch            Ticket     Fare Cabin  \
# 0       3    male  22.0      1      0         A/5 21171   7.2500   NaN
# 1       1  female  38.0      1      0          PC 17599  71.2833   C85
# 2       3  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN
#
#   Embarked
# 0        S
# 1        C
# 2        S

# %%
df.iloc[[0,1,2,3],[0,1,2,3,4,5,6]]
# Out:
#                                                 Name  PassengerId  Survived  \
# 0                            Braund, Mr. Owen Harris            1         0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...            2         1
# 2                             Heikkinen, Miss. Laina            3         1
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)            4         1
#
#    Pclass     Sex   Age  SibSp
# 0       3    male  22.0      1
# 1       1  female  38.0      1
# 2       3  female  26.0      0
# 3       1  female  35.0      1

# %%
df.loc[(df['Sex']=='male') & (df['Age']>40)]
# Out:
#                                Name  PassengerId  Survived  Pclass   Sex  \
# 6           McCarthy, Mr. Timothy J            7         0       1  male
# 33            Wheadon, Mr. Edward H           34         0       2  male
# 35   Holverson, Mr. Alexander Oskar           36         0       1  male
# 54   Ostby, Mr. Engelhart Cornelius           55         0       1  male
# 62      Harris, Mr. Henry Birkhardt           63         0       1  male
# ..                              ...          ...       ...     ...   ...
# 845             Abbing, Mr. Anthony          846         0       3  male
# 851             Svensson, Mr. Johan          852         0       3  male
# 857          Daly, Mr. Peter Denis           858         1       1  male
# 860         Hansen, Mr. Claus Peter          861         0       3  male
# 873     Vander Cruyssen, Mr. Victor          874         0       3  male
#
#       Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 6    54.0      0      0       17463  51.8625   E46        S
# 33   66.0      0      0  C.A. 24579  10.5000   NaN        S
# 35   42.0      1      0      113789  52.0000   NaN        S
# 54   65.0      0      1      113509  61.9792   B30        C
# 62   45.0      1      0       36973  83.4750   C83        S
# ..    ...    ...    ...         ...      ...   ...      ...
# 845  42.0      0      0   C.A. 5547   7.5500   NaN        S
# 851  74.0      0      0      347060   7.7750   NaN        S
# 857  51.0      0      0      113055  26.5500   E17        S
# 860  41.0      2      0      350026  14.1083   NaN        S
# 873  47.0      0      0      345765   9.0000   NaN        S
#
# [102 rows x 12 columns]

# %%
df.loc[(df['Fare']>30) & (df['Survived']==1)]
# Out:
#                                                   Name  PassengerId  Survived  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...            2         1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)            4         1
# 9                  Nasser, Mrs. Nicholas (Adele Achem)           10         1
# 23                        Sloper, Mr. William Thompson           24         1
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...           26         1
# ..                                                 ...          ...       ...
# 849       Goldenberg, Mrs. Samuel L (Edwiga Grabowska)          850         1
# 853                          Lines, Miss. Mary Conover          854         1
# 856         Wick, Mrs. George Dennick (Mary Hitchcock)          857         1
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)          872         1
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)          880         1
#
#      Pclass     Sex   Age  SibSp  Parch    Ticket      Fare Cabin Embarked
# 1         1  female  38.0      1      0  PC 17599   71.2833   C85        C
# 3         1  female  35.0      1      0    113803   53.1000  C123        S
# 9         2  female  14.0      1      0    237736   30.0708   NaN        C
# 23        1    male  28.0      0      0    113788   35.5000    A6        S
# 25        3  female  38.0      1      5    347077   31.3875   NaN        S
# ..      ...     ...   ...    ...    ...       ...       ...   ...      ...
# 849       1  female   NaN      1      0     17453   89.1042   C92        C
# 853       1  female  16.0      0      1  PC 17592   39.4000   D28        S
# 856       1  female  45.0      1      1     36928  164.8667   NaN        S
# 871       1  female  47.0      1      1     11751   52.5542   D35        S
# 879       1  female  56.0      0      1     11767   83.1583   C50        C
#
# [136 rows x 12 columns]

# %%
df.loc[(df['Fare']>30) & (df['Survived']==1)].shape[0]
# Out:
# 136

# %%
df.loc[(df['Sex']=='female') & (df['Survived']==0)]
# Out:
#                                                   Name  PassengerId  Survived  \
# 14                Vestrom, Miss. Hulda Amanda Adolfina           15         0
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...           19         0
# 24                       Palsson, Miss. Torborg Danira           25         0
# 38                  Vander Planke, Miss. Augusta Maria           39         0
# 40      Ahlin, Mrs. Johan (Johanna Persdotter Larsson)           41         0
# ..                                                 ...          ...       ...
# 854      Carter, Mrs. Ernest Courtenay (Lilian Hughes)          855         0
# 863                  Sage, Miss. Dorothy Edith "Dolly"          864         0
# 882                       Dahlberg, Miss. Gerda Ulrika          883         0
# 885               Rice, Mrs. William (Margaret Norton)          886         0
# 888           Johnston, Miss. Catherine Helen "Carrie"          889         0
#
#      Pclass     Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 14        3  female  14.0      0      0      350406   7.8542   NaN        S
# 18        3  female  31.0      1      0      345763  18.0000   NaN        S
# 24        3  female   8.0      3      1      349909  21.0750   NaN        S
# 38        3  female  18.0      2      0      345764  18.0000   NaN        S
# 40        3  female  40.0      1      0        7546   9.4750   NaN        S
# ..      ...     ...   ...    ...    ...         ...      ...   ...      ...
# 854       2  female  44.0      1      0      244252  26.0000   NaN        S
# 863       3  female   NaN      8      2    CA. 2343  69.5500   NaN        S
# 882       3  female  22.0      0      0        7552  10.5167   NaN        S
# 885       3  female  39.0      0      5      382652  29.1250   NaN        Q
# 888       3  female   NaN      1      2  W./C. 6607  23.4500   NaN        S
#
# [81 rows x 12 columns]

# %%
df.loc[(df['Pclass']==1) | (df['Pclass']==2)]
# Out:
#                                                   Name  PassengerId  Survived  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...            2         1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)            4         1
# 6                              McCarthy, Mr. Timothy J            7         0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)           10         1
# 11                            Bonnell, Miss. Elizabeth           12         1
# ..                                                 ...          ...       ...
# 880       Shelley, Mrs. William (Imanita Parrish Hall)          881         1
# 883                      Banfield, Mr. Frederick James          884         0
# 886                              Montvila, Rev. Juozas          887         0
# 887                       Graham, Miss. Margaret Edith          888         1
# 889                              Behr, Mr. Karl Howell          890         1
#
#      Pclass     Sex   Age  SibSp  Parch            Ticket     Fare Cabin  \
# 1         1  female  38.0      1      0          PC 17599  71.2833   C85
# 3         1  female  35.0      1      0            113803  53.1000  C123
# 6         1    male  54.0      0      0             17463  51.8625   E46
# 9         2  female  14.0      1      0            237736  30.0708   NaN
# 11        1  female  58.0      0      0            113783  26.5500  C103
# ..      ...     ...   ...    ...    ...               ...      ...   ...
# 880       2  female  25.0      0      1            230433  26.0000   NaN
# 883       2    male  28.0      0      0  C.A./SOTON 34068  10.5000   NaN
# 886       2    male  27.0      0      0            211536  13.0000   NaN
# 887       1  female  19.0      0      0            112053  30.0000   B42
# 889       1    male  26.0      0      0            111369  30.0000  C148
#
#     Embarked
# 1          C
# 3          S
# 6          S
# 9          C
# 11         S
# ..       ...
# 880        S
# 883        S
# 886        S
# 887        S
# 889        C
#
# [400 rows x 12 columns]

# %%
df.loc[(df['SibSp']>2 & (df['Survived']==0))]
# Out:
#                                                   Name  PassengerId  Survived  \
# 0                              Braund, Mr. Owen Harris            1         0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...            2         1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)            4         1
# 7                       Palsson, Master. Gosta Leonard            8         0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)           10         1
# ..                                                 ...          ...       ...
# 866                       Duran y More, Miss. Asuncion          867         1
# 869                    Johnson, Master. Harold Theodor          870         1
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)          872         1
# 874              Abelson, Mrs. Samuel (Hannah Wizosky)          875         1
# 888           Johnston, Miss. Catherine Helen "Carrie"          889         0
#
#      Pclass     Sex   Age  SibSp  Parch         Ticket     Fare Cabin Embarked
# 0         3    male  22.0      1      0      A/5 21171   7.2500   NaN        S
# 1         1  female  38.0      1      0       PC 17599  71.2833   C85        C
# 3         1  female  35.0      1      0         113803  53.1000  C123        S
# 7         3    male   2.0      3      1         349909  21.0750   NaN        S
# 9         2  female  14.0      1      0         237736  30.0708   NaN        C
# ..      ...     ...   ...    ...    ...            ...      ...   ...      ...
# 866       2  female  27.0      1      0  SC/PARIS 2149  13.8583   NaN        C
# 869       3    male   4.0      1      1         347742  11.1333   NaN        S
# 871       1  female  47.0      1      1          11751  52.5542   D35        S
# 874       2  female  28.0      1      0      P/PP 3381  24.0000   NaN        C
# 888       3  female   NaN      1      2     W./C. 6607  23.4500   NaN        S
#
# [283 rows x 12 columns]

# %%
df.loc[(df['Pclass']==3)&(df['Age']>30)]
# Out:
#                                                   Name  PassengerId  Survived  \
# 4                             Allen, Mr. William Henry            5         0
# 13                         Andersson, Mr. Anders Johan           14         0
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...           19         0
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...           26         1
# 40      Ahlin, Mrs. Johan (Johanna Persdotter Larsson)           41         0
# ..                                                 ...          ...       ...
# 860                            Hansen, Mr. Claus Peter          861         0
# 873                        Vander Cruyssen, Mr. Victor          874         0
# 881                                 Markun, Mr. Johann          882         0
# 885               Rice, Mrs. William (Margaret Norton)          886         0
# 890                                Dooley, Mr. Patrick          891         0
#
#      Pclass     Sex   Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 4         3    male  35.0      0      0  373450   8.0500   NaN        S
# 13        3    male  39.0      1      5  347082  31.2750   NaN        S
# 18        3  female  31.0      1      0  345763  18.0000   NaN        S
# 25        3  female  38.0      1      5  347077  31.3875   NaN        S
# 40        3  female  40.0      1      0    7546   9.4750   NaN        S
# ..      ...     ...   ...    ...    ...     ...      ...   ...      ...
# 860       3    male  41.0      2      0  350026  14.1083   NaN        S
# 873       3    male  47.0      0      0  345765   9.0000   NaN        S
# 881       3    male  33.0      0      0  349257   7.8958   NaN        S
# 885       3  female  39.0      0      5  382652  29.1250   NaN        Q
# 890       3    male  32.0      0      0  370376   7.7500   NaN        Q
#
# [103 rows x 12 columns]

# %%
df.loc[(df['Age']<15 & (df['Parch']>0))]
# Out:
#                                 Name  PassengerId  Survived  Pclass     Sex  \
# 78     Caldwell, Master. Alden Gates           79         1       2    male
# 305   Allison, Master. Hudson Trevor          306         1       1    male
# 469    Baclini, Miss. Helene Barbara          470         1       3  female
# 644           Baclini, Miss. Eugenie          645         1       3  female
# 755        Hamalainen, Master. Viljo          756         1       2    male
# 803  Thomas, Master. Assad Alexander          804         1       3    male
# 831  Richards, Master. George Sibley          832         1       2    male
#
#       Age  SibSp  Parch  Ticket      Fare    Cabin Embarked
# 78   0.83      0      2  248738   29.0000      NaN        S
# 305  0.92      1      2  113781  151.5500  C22 C26        S
# 469  0.75      2      1    2666   19.2583      NaN        C
# 644  0.75      2      1    2666   19.2583      NaN        C
# 755  0.67      1      1  250649   14.5000      NaN        S
# 803  0.42      0      1    2625    8.5167      NaN        C
# 831  0.83      1      1   29106   18.7500      NaN        S

# %%
df.loc[(df['Sex']=='male') & (df['Fare']<10)]
# Out:
#                                Name  PassengerId  Survived  Pclass   Sex  \
# 0           Braund, Mr. Owen Harris            1         0       3  male
# 4          Allen, Mr. William Henry            5         0       3  male
# 5                  Moran, Mr. James            6         0       3  male
# 12   Saundercock, Mr. William Henry           13         0       3  male
# 26          Emir, Mr. Farred Chehab           27         0       3  male
# ..                              ...          ...       ...     ...   ...
# 877            Petroff, Mr. Nedelio          878         0       3  male
# 878              Laleff, Mr. Kristo          879         0       3  male
# 881              Markun, Mr. Johann          882         0       3  male
# 884          Sutehall, Mr. Henry Jr          885         0       3  male
# 890             Dooley, Mr. Patrick          891         0       3  male
#
#       Age  SibSp  Parch           Ticket    Fare Cabin Embarked
# 0    22.0      1      0        A/5 21171  7.2500   NaN        S
# 4    35.0      0      0           373450  8.0500   NaN        S
# 5     NaN      0      0           330877  8.4583   NaN        Q
# 12   20.0      0      0        A/5. 2151  8.0500   NaN        S
# 26    NaN      0      0             2631  7.2250   NaN        C
# ..    ...    ...    ...              ...     ...   ...      ...
# 877  19.0      0      0           349212  7.8958   NaN        S
# 878   NaN      0      0           349217  7.8958   NaN        S
# 881  33.0      0      0           349257  7.8958   NaN        S
# 884  25.0      0      0  SOTON/OQ 392076  7.0500   NaN        S
# 890  32.0      0      0           370376  7.7500   NaN        Q
#
# [272 rows x 12 columns]

# %%
df.loc[0:,:]
# Out:
#                                                   Name  PassengerId  Survived  \
# 0                              Braund, Mr. Owen Harris            1         0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...            2         1
# 2                               Heikkinen, Miss. Laina            3         1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)            4         1
# 4                             Allen, Mr. William Henry            5         0
# ..                                                 ...          ...       ...
# 886                              Montvila, Rev. Juozas          887         0
# 887                       Graham, Miss. Margaret Edith          888         1
# 888           Johnston, Miss. Catherine Helen "Carrie"          889         0
# 889                              Behr, Mr. Karl Howell          890         1
# 890                                Dooley, Mr. Patrick          891         0
#
#      Pclass     Sex   Age  SibSp  Parch            Ticket     Fare Cabin  \
# 0         3    male  22.0      1      0         A/5 21171   7.2500   NaN
# 1         1  female  38.0      1      0          PC 17599  71.2833   C85
# 2         3  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN
# 3         1  female  35.0      1      0            113803  53.1000  C123
# 4         3    male  35.0      0      0            373450   8.0500   NaN
# ..      ...     ...   ...    ...    ...               ...      ...   ...
# 886       2    male  27.0      0      0            211536  13.0000   NaN
# 887       1  female  19.0      0      0            112053  30.0000   B42
# 888       3  female   NaN      1      2        W./C. 6607  23.4500   NaN
# 889       1    male  26.0      0      0            111369  30.0000  C148
# 890       3    male  32.0      0      0            370376   7.7500   NaN
#
#     Embarked
# 0          S
# 1          C
# 2          S
# 3          S
# 4          S
# ..       ...
# 886        S
# 887        S
# 888        S
# 889        C
# 890        Q
#
# [891 rows x 12 columns]

# %%
df.loc[::-1,::-1]
# Out:
#     Embarked Cabin     Fare            Ticket  Parch  SibSp   Age     Sex  \
# 890        Q   NaN   7.7500            370376      0      0  32.0    male
# 889        C  C148  30.0000            111369      0      0  26.0    male
# 888        S   NaN  23.4500        W./C. 6607      2      1   NaN  female
# 887        S   B42  30.0000            112053      0      0  19.0  female
# 886        S   NaN  13.0000            211536      0      0  27.0    male
# ..       ...   ...      ...               ...    ...    ...   ...     ...
# 4          S   NaN   8.0500            373450      0      0  35.0    male
# 3          S  C123  53.1000            113803      0      1  35.0  female
# 2          S   NaN   7.9250  STON/O2. 3101282      0      0  26.0  female
# 1          C   C85  71.2833          PC 17599      0      1  38.0  female
# 0          S   NaN   7.2500         A/5 21171      0      1  22.0    male
#
#      Pclass  Survived  PassengerId  \
# 890       3         0          891
# 889       1         1          890
# 888       3         0          889
# 887       1         1          888
# 886       2         0          887
# ..      ...       ...          ...
# 4         3         0            5
# 3         1         1            4
# 2         3         1            3
# 1         1         1            2
# 0         3         0            1
#
#                                                   Name
# 890                                Dooley, Mr. Patrick
# 889                              Behr, Mr. Karl Howell
# 888           Johnston, Miss. Catherine Helen "Carrie"
# 887                       Graham, Miss. Margaret Edith
# 886                              Montvila, Rev. Juozas
# ..                                                 ...
# 4                             Allen, Mr. William Henry
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 2                               Heikkinen, Miss. Laina
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 0                              Braund, Mr. Owen Harris
#
# [891 rows x 12 columns]

# %%
df1= df.loc[(df['Sex']=='male') & (df['Embarked']=='S')]

# %%
df1
# Out:
#                                Name  PassengerId  Survived  Pclass   Sex  \
# 0           Braund, Mr. Owen Harris            1         0       3  male
# 4          Allen, Mr. William Henry            5         0       3  male
# 6           McCarthy, Mr. Timothy J            7         0       1  male
# 7    Palsson, Master. Gosta Leonard            8         0       3  male
# 12   Saundercock, Mr. William Henry           13         0       3  male
# ..                              ...          ...       ...     ...   ...
# 878              Laleff, Mr. Kristo          879         0       3  male
# 881              Markun, Mr. Johann          882         0       3  male
# 883   Banfield, Mr. Frederick James          884         0       2  male
# 884          Sutehall, Mr. Henry Jr          885         0       3  male
# 886           Montvila, Rev. Juozas          887         0       2  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    22.0      1      0         A/5 21171   7.2500   NaN        S
# 4    35.0      0      0            373450   8.0500   NaN        S
# 6    54.0      0      0             17463  51.8625   E46        S
# 7     2.0      3      1            349909  21.0750   NaN        S
# 12   20.0      0      0         A/5. 2151   8.0500   NaN        S
# ..    ...    ...    ...               ...      ...   ...      ...
# 878   NaN      0      0            349217   7.8958   NaN        S
# 881  33.0      0      0            349257   7.8958   NaN        S
# 883  28.0      0      0  C.A./SOTON 34068  10.5000   NaN        S
# 884  25.0      0      0   SOTON/OQ 392076   7.0500   NaN        S
# 886  27.0      0      0            211536  13.0000   NaN        S
#
# [441 rows x 12 columns]

# %%
df2= df.loc[(df['Sex']=='male') & (df['Embarked']=='C')]

# %%
df2
# Out:
#                            Name  PassengerId  Survived  Pclass   Sex   Age  \
# 26      Emir, Mr. Farred Chehab           27         0       3  male   NaN
# 30     Uruchurtu, Don. Manuel E           31         0       1  male  40.0
# 34      Meyer, Mr. Edgar Joseph           35         0       1  male  28.0
# 36             Mamee, Mr. Hanna           37         1       3  male   NaN
# 42          Kraeff, Mr. Theodor           43         0       3  male   NaN
# ..                          ...          ...       ...     ...   ...   ...
# 839        Marechal, Mr. Pierre          840         1       1  male   NaN
# 843  Lemberopolous, Mr. Peter L          844         0       3  male  34.5
# 847          Markoff, Mr. Marin          848         0       3  male  35.0
# 859            Razi, Mr. Raihed          860         0       3  male   NaN
# 889       Behr, Mr. Karl Howell          890         1       1  male  26.0
#
#      SibSp  Parch    Ticket     Fare Cabin Embarked
# 26       0      0      2631   7.2250   NaN        C
# 30       0      0  PC 17601  27.7208   NaN        C
# 34       1      0  PC 17604  82.1708   NaN        C
# 36       0      0      2677   7.2292   NaN        C
# 42       0      0    349253   7.8958   NaN        C
# ..     ...    ...       ...      ...   ...      ...
# 839      0      0     11774  29.7000   C47        C
# 843      0      0      2683   6.4375   NaN        C
# 847      0      0    349213   7.8958   NaN        C
# 859      0      0      2629   7.2292   NaN        C
# 889      0      0    111369  30.0000  C148        C
#
# [95 rows x 12 columns]

# %%
df3=pd.concat([df1,df2])

# %%
df3
# Out:
#                                Name  PassengerId  Survived  Pclass   Sex  \
# 0           Braund, Mr. Owen Harris            1         0       3  male
# 4          Allen, Mr. William Henry            5         0       3  male
# 6           McCarthy, Mr. Timothy J            7         0       1  male
# 7    Palsson, Master. Gosta Leonard            8         0       3  male
# 12   Saundercock, Mr. William Henry           13         0       3  male
# ..                              ...          ...       ...     ...   ...
# 839            Marechal, Mr. Pierre          840         1       1  male
# 843      Lemberopolous, Mr. Peter L          844         0       3  male
# 847              Markoff, Mr. Marin          848         0       3  male
# 859                Razi, Mr. Raihed          860         0       3  male
# 889           Behr, Mr. Karl Howell          890         1       1  male
#
#       Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# 0    22.0      1      0  A/5 21171   7.2500   NaN        S
# 4    35.0      0      0     373450   8.0500   NaN        S
# 6    54.0      0      0      17463  51.8625   E46        S
# 7     2.0      3      1     349909  21.0750   NaN        S
# 12   20.0      0      0  A/5. 2151   8.0500   NaN        S
# ..    ...    ...    ...        ...      ...   ...      ...
# 839   NaN      0      0      11774  29.7000   C47        C
# 843  34.5      0      0       2683   6.4375   NaN        C
# 847  35.0      0      0     349213   7.8958   NaN        C
# 859   NaN      0      0       2629   7.2292   NaN        C
# 889  26.0      0      0     111369  30.0000  C148        C
#
# [536 rows x 12 columns]

# %%
path1 = "/content/weather_data.csv"

# %%
dfw=pd.read_csv(path1)

# %%
dfw
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
x=dfw.groupby('event')['temperature'].mean()

# %%
x
# Out:
# event
# Rain     32.0
# Snow     26.0
# Sunny    33.0
# Name: temperature, dtype: float64

# %%
x.reset_index()
# Out:
#    event  temperature
# 0   Rain         32.0
# 1   Snow         26.0
# 2  Sunny         33.0

# %%
x=dfw.groupby('event')['temperature'].agg(['sum','mean']).reset_index()

# %%
x
# Out:
#    event  sum  mean
# 0   Rain   64  32.0
# 1   Snow   52  26.0
# 2  Sunny   66  33.0

# %%
x.sort_values('mean')
# Out:
#    event  sum  mean
# 1   Snow   52  26.0
# 0   Rain   64  32.0
# 2  Sunny   66  33.0

# %%
x.sort_values('mean',ascending=False)
# Out:
#    event  sum  mean
# 2  Sunny   66  33.0
# 0   Rain   64  32.0
# 1   Snow   52  26.0

# %%
z=df.groupby('Sex').agg({'Fare':'sum','Age':'mean'}).sort_values('Fare',ascending=False)

# %%
z
# Out:
#               Fare        Age
# Sex
# male    14727.2865  30.726645
# female  13966.6628  27.915709

# %%
df.groupby('Pclass')['Age'].mean().sort_values(ascending=False)
# Out:
# Pclass
# 1    38.233441
# 2    29.877630
# 3    25.140620
# Name: Age, dtype: float64

# %%
x1=df.loc[(df['Survived']==0)].shape[0]

# %%
x1
# Out:
# 549

# %%
df.groupby('Survived').size().sort_values(ascending=False)
# Out:
# Survived
# 0    549
# 1    342
# dtype: int64

# %%
df.groupby('Embarked')['Age'].agg(['max','min']).sort_values(by='max',ascending=False)
# Out:
#            max   min
# Embarked
# S         80.0  0.67
# C         71.0  0.42
# Q         70.5  2.00

# %%
df.groupby('Embarked')['Fare'].sum().sort_values(ascending=False)
# Out:
# Embarked
# S    17439.3988
# C    10072.2962
# Q     1022.2543
# Name: Fare, dtype: float64

# %%
df.groupby('Pclass')['Age'].median().sort_values(ascending=False)
# Out:
# Pclass
# 1    37.0
# 2    29.0
# 3    24.0
# Name: Age, dtype: float64

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
def Fare_category(x):
  if x<20:
    return 'Low Fare'
  elif   x>20 and x<100:
      return 'Medium Fare'
  else:
     return 'High Fare'

# %%
df['Fare category']=df['Fare'].apply(Fare_category)

# %%
df
# Out:
#                                                   Name  PassengerId  Survived  \
# 0                              Braund, Mr. Owen Harris            1         0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...            2         1
# 2                               Heikkinen, Miss. Laina            3         1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)            4         1
# 4                             Allen, Mr. William Henry            5         0
# ..                                                 ...          ...       ...
# 886                              Montvila, Rev. Juozas          887         0
# 887                       Graham, Miss. Margaret Edith          888         1
# 888           Johnston, Miss. Catherine Helen "Carrie"          889         0
# 889                              Behr, Mr. Karl Howell          890         1
# 890                                Dooley, Mr. Patrick          891         0
#
#      Pclass     Sex   Age  SibSp  Parch            Ticket     Fare Cabin  \
# 0         3    male  22.0      1      0         A/5 21171   7.2500   NaN
# 1         1  female  38.0      1      0          PC 17599  71.2833   C85
# 2         3  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN
# 3         1  female  35.0      1      0            113803  53.1000  C123
# 4         3    male  35.0      0      0            373450   8.0500   NaN
# ..      ...     ...   ...    ...    ...               ...      ...   ...
# 886       2    male  27.0      0      0            211536  13.0000   NaN
# 887       1  female  19.0      0      0            112053  30.0000   B42
# 888       3  female   NaN      1      2        W./C. 6607  23.4500   NaN
# 889       1    male  26.0      0      0            111369  30.0000  C148
# 890       3    male  32.0      0      0            370376   7.7500   NaN
#
#     Embarked Fare category
# 0          S      Low Fare
# 1          C   Medium Fare
# 2          S      Low Fare
# 3          S   Medium Fare
# 4          S      Low Fare
# ..       ...           ...
# 886        S      Low Fare
# 887        S   Medium Fare
# 888        S   Medium Fare
# 889        C   Medium Fare
# 890        Q      Low Fare
#
# [891 rows x 13 columns]

# %%
df['encoded Embarked']=df['Embarked'].map({'S':0,'C':1,'Q':2})

# %%
df
# Out:
#                                                   Name  PassengerId  Survived  \
# 0                              Braund, Mr. Owen Harris            1         0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...            2         1
# 2                               Heikkinen, Miss. Laina            3         1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)            4         1
# 4                             Allen, Mr. William Henry            5         0
# ..                                                 ...          ...       ...
# 886                              Montvila, Rev. Juozas          887         0
# 887                       Graham, Miss. Margaret Edith          888         1
# 888           Johnston, Miss. Catherine Helen "Carrie"          889         0
# 889                              Behr, Mr. Karl Howell          890         1
# 890                                Dooley, Mr. Patrick          891         0
#
#      Pclass     Sex   Age  SibSp  Parch            Ticket     Fare Cabin  \
# 0         3    male  22.0      1      0         A/5 21171   7.2500   NaN
# 1         1  female  38.0      1      0          PC 17599  71.2833   C85
# 2         3  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN
# 3         1  female  35.0      1      0            113803  53.1000  C123
# 4         3    male  35.0      0      0            373450   8.0500   NaN
# ..      ...     ...   ...    ...    ...               ...      ...   ...
# 886       2    male  27.0      0      0            211536  13.0000   NaN
# 887       1  female  19.0      0      0            112053  30.0000   B42
# 888       3  female   NaN      1      2        W./C. 6607  23.4500   NaN
# 889       1    male  26.0      0      0            111369  30.0000  C148
# 890       3    male  32.0      0      0            370376   7.7500   NaN
#
#     Embarked Fare category  encoded Embarked
# 0          S      Low Fare               0.0
# 1          C   Medium Fare               1.0
# 2          S      Low Fare               0.0
# 3          S   Medium Fare               0.0
# 4          S      Low Fare               0.0
# ..       ...           ...               ...
# 886        S      Low Fare               0.0
# 887        S   Medium Fare               0.0
# 888        S   Medium Fare               0.0
# 889        C   Medium Fare               1.0
# 890        Q      Low Fare               2.0
#
# [891 rows x 14 columns]

# %%
path="/content/Titanic-Dataset.csv"

# %%
df=pd.read_csv(path)

# %%
path1="/content/weather_data.csv"

# %%
dfw=pd.read_csv(path1)

# %%
df['Encoded Embarked1']=df['Embarked'].map({'S':3,'C':4,'Q':5})

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked  Encoded Embarked1
# 0        0         A/5 21171   7.2500   NaN        S                3.0
# 1        0          PC 17599  71.2833   C85        C                4.0
# 2        0  STON/O2. 3101282   7.9250   NaN        S                3.0
# 3        0            113803  53.1000  C123        S                3.0
# 4        0            373450   8.0500   NaN        S                3.0
# ..     ...               ...      ...   ...      ...                ...
# 886      0            211536  13.0000   NaN        S                3.0
# 887      0            112053  30.0000   B42        S                3.0
# 888      2        W./C. 6607  23.4500   NaN        S                3.0
# 889      0            111369  30.0000  C148        C                4.0
# 890      0            370376   7.7500   NaN        Q                5.0
#
# [891 rows x 13 columns]

# %%
df.groupby('Embarked').agg({'Age':'mean','Fare':'sum'}).sort_values(by='Age',ascending=False)
# Out:
#                 Age        Fare
# Embarked
# C         30.814769  10072.2962
# S         29.445397  17439.3988
# Q         28.089286   1022.2543

# %%
df.groupby('Embarked')['Fare'].agg(['sum','mean']).sort_values('sum',ascending=False)
# Out:
#                  sum       mean
# Embarked
# S         17439.3988  27.079812
# C         10072.2962  59.954144
# Q          1022.2543  13.276030

# %%
df.groupby('Embarked').agg({'Fare':'sum','Age':'mean'}).sort_values('Age')
# Out:
#                 Fare        Age
# Embarked
# Q          1022.2543  28.089286
# S         17439.3988  29.445397
# C         10072.2962  30.814769

# %%
df.groupby('Embarked')['Age'].agg(['max','min']).sort_values(by='max',ascending=False)
# Out:
#            max   min
# Embarked
# S         80.0  0.67
# C         71.0  0.42
# Q         70.5  2.00
